# %%
import pandas as pd
import numpy as np

# %%
Roles = pd.read_csv('../data/Roles.csv')
Roles.head()
# Out:
#             Role                                        Description Alignment  \
# 0         Artist  Privately, during the day, you may return home...      Town
# 1        Atheist  The storyteller can break the rules. If the st...      Town
# 2     Balloonist  Nightly, learn the name of a living player of ...      Town
# 3  Bounty Hunter  Start knowing 1 evil player. If they die, lear...      Town
# 4       Cannibal  Gain the ability of the last executed person. ...      Town
#
#   Difficulty
# 0        NaN
# 1        ***
# 2          *
# 3         **
# 4        NaN

# %%
InputRoles = ["Artist", "Noble", "Poisoner", "Scarlet Woman", "Spy", "Witch", "Prophet", "Sailor", "Soldier", "Tea Lady", "Drunk", "Balloonist", "Flower Girl", "Investigator", "Fang Gu", "Ojo", "Prisdelo", "Vigormortis" "Ravenkeeper", "Magician", "Mayor", "Monk",  "Moleman", "Ogre", "Recluse", "Sweetheart", "Baron"]

# %%
WorkingScript = Roles[Roles['Role'].isin(InputRoles)]
WorkingScript
# Out:
#              Role                                        Description  \
# 0          Artist  Privately, during the day, you may return home...
# 2      Balloonist  Nightly, learn the name of a living player of ...
# 9     Flower Girl         Nightly, learn if the demon voted that day
# 16   Investigator   Start knowing 1 of 2 people is a specific minion
# 19       Magician  The minion is told that either you or the demo...
# 20          Mayor  If nobody is executed in the final 3, town win...
# 21           Monk  Nightly, choose someone to protect from the demon
# 23          Noble  Start with a list of 2 good players and 1 evil...
# 28        Prophet  If a team has not yet won 3 days after your de...
# 30         Sailor  You can't die. Nightly, choose a living player...
# 33        Soldier             Cannot be killed by the demon at night
# 34       Tea Lady  If both of your living neighbors are good, nei...
# 40          Drunk  You think you are a specific town role that is...
# 45        Moleman  Each night, choose three living players (befor...
# 46           Ogre  On the first night, pick a player. You are the...
# 48        Recluse  May register as some manner of evil to other r...
# 50     Sweetheart  When you die, a player becomes a drunk for the...
# 53          Baron                                       +2 Outsiders
# 61       Poisoner  Nightly, poison 1 player until the next night ...
# 62  Scarlet Woman  If the demon dies when there are 5 or more peo...
# 64            Spy  Nightly, learn all roles. You may appear as go...
# 65          Witch  Nightly, choose a player. If they nominate som...
# 67        Fang Gu  Nightly, choose a living player to die. The fi...
# 72            Ojo  Nightly, choose a role. If a player with that ...
# 73       Prisdelo  Nightly, choose 3 living players. Each is info...
#
#    Alignment Difficulty
# 0       Town        NaN
# 2       Town          *
# 9       Town        NaN
# 16      Town        NaN
# 19      Town          *
# 20      Town        NaN
# 21      Town        NaN
# 23      Town        NaN
# 28      Town        NaN
# 30      Town          *
# 33      Town        NaN
# 34      Town        NaN
# 40  Outsider        NaN
# 45  Outsider          *
# 46  Outsider          *
# 48  Outsider        NaN
# 50  Outsider        NaN
# 53    Minion        NaN
# 61    Minion        NaN
# 62    Minion        NaN
# 64    Minion        NaN
# 65    Minion        NaN
# 67     Demon        NaN
# 72     Demon        NaN
# 73     Demon          *

# %%
def print_glossary(working_script):
    alignment_check = ""
    for i in working_script.index:
        # Checks if there is a new type
        if alignment_check != working_script['Alignment'][i]:
            print("")
            print(f"# **{working_script['Alignment'][i]}**")
            alignment_check = working_script['Alignment'][i]
        
        # Checks the difficulty
        if type(working_script['Difficulty'][i]) == float:
            working_difficulty = ""
        else:
            working_difficulty = working_script['Difficulty'][i]
            
        # Output
        print(f"**{working_script['Role'][i]}{working_difficulty}** {working_script['Description'][i]}")
        
def print_outline(working_script):
    alignment_check = ""
    for i in working_script.index:
        # Checks if there is a new type
        if alignment_check != working_script['Alignment'][i]:
            print("")
            print(f"# **{working_script['Alignment'][i]}**")
            alignment_check = working_script['Alignment'][i]
        
        # Checks the difficulty
        if type(working_script['Difficulty'][i]) == float:
            working_difficulty = ""
        else:
            working_difficulty = working_script['Difficulty'][i]
            
        # Output
        print(f"**{working_script['Role'][i]}{working_difficulty}**")
        
def save_script(working_script, filename):
    working_script.to_csv(f"../data/{filename}.csv", index=False, header=True)
    
def fetch_script(filename):
    return pd.read_csv(f"../data/{filename}.csv")

def make_script(input_roles):
    return Roles[Roles['Role'].isin(input_roles)]

# %%
save_script(WorkingScript, "The Drink")
# Out:
# # **Town**
# **Artist** Privately, during the day, you may return home to ask the storyteller any one yes or no question
# **Balloonist*** Nightly, learn the name of a living player of a different type from (demon, minion, outsider, or town) than last night. There might be +1 outsider
# **Flower Girl** Nightly, learn if the demon voted that day
# **Investigator** Start knowing 1 of 2 people is a specific minion
# **Magician*** The minion is told that either you or the demon is their demon, and the demon is told that either you or the minion is their minion
# **Mayor** If nobody is executed in the final 3, town wins. When you are attacked, another town may die instead
# **Monk** Nightly, choose someone to protect from the demon
# **Noble** Start with a list of 2 good players and 1 evil, you don't know which is which
# **Prophet** If a team has not yet won 3 days after your death, you return to life and cannot be killed again by the same method
# **Sailor*** You can't die. Nightly, choose a living player, who is told they were visited by the Sailor. You or they are drunk until the start of the next night
# **Soldier** Cannot be killed by the demon at night
# **Tea Lady** If both of your living neighbors are good, neither can die
#
# # **Outsider**
# **Drunk** You think you are a specific town role that is not in play, but your ability doesn’t work
# **Moleman*** Each night, choose three living players (before anyone dies that night). If one is executed the following day, one of the other two, if alive, will be instead
# **Ogre*** On the first night, pick a player. You are their alignment for the rest of the game, but are not told what that alignment is
# **Recluse** May register as some manner of evil to other role abilities, even after dying
# **Sweetheart** When you die, a player becomes a drunk for the rest of the game
#
# # **Minion**
# **Baron** +2 Outsiders
# **Poisoner** Nightly, poison 1 player until the next night begins
# **Scarlet Woman** If the demon dies when there are 5 or more people alive, you become the demon
# **Spy** Nightly, learn all roles. You may appear as good to role abilities
# **Witch** Nightly, choose a player. If they nominate someone, they die. This ability is disabled the moment 3 or less people remain alive
#
# # **Demon**
# **Fang Gu** Nightly, choose a living player to die. The first time per game an outsider is killed like this, the original Fang Gu dies and the targeted outsider becomes the new Fang Gu. +1 Outsider instead of town
# **Ojo** Nightly, choose a role. If a player with that role exists, they die. If nobody has the role, the storyteller decides who dies
# **Prisdelo*** Nightly, choose 3 living players. Each is informed that they have been selected. Each must individually choose whether to live or die. If all choose to live, all die

# %%
print_outline(WorkingScript)
# Out:
# # **Town**
# **Artist**
# **Balloonist***
# **Flower Girl**
# **Investigator**
# **Magician***
# **Mayor**
# **Monk**
# **Noble**
# **Prophet**
# **Sailor***
# **Soldier**
# **Tea Lady**
#
# # **Outsider**
# **Drunk**
# **Moleman***
# **Ogre***
# **Recluse**
# **Sweetheart**
#
# # **Minion**
# **Baron**
# **Poisoner**
# **Scarlet Woman**
# **Spy**
# **Witch**
#
# # **Demon**
# **Fang Gu**
# **Ojo**
# **Prisdelo***

# %%
print_glossary(WorkingScript)
# Out:
# # **Town**
# **Artist** Privately, during the day, you may return home to ask the storyteller any one yes or no question
# **Balloonist*** Nightly, learn the name of a living player of a different type from (demon, minion, outsider, or town) than last night. There might be +1 outsider
# **Flower Girl** Nightly, learn if the demon voted that day
# **Investigator** Start knowing 1 of 2 people is a specific minion
# **Magician*** The minion is told that either you or the demon is their demon, and the demon is told that either you or the minion is their minion
# **Mayor** If nobody is executed in the final 3, town wins. When you are attacked, another town may die instead
# **Monk** Nightly, choose someone to protect from the demon
# **Noble** Start with a list of 2 good players and 1 evil, you don't know which is which
# **Prophet** If a team has not yet won 3 days after your death, you return to life and cannot be killed again by the same method
# **Sailor*** You can't die. Nightly, choose a living player, who is told they were visited by the Sailor. You or they are drunk until the start of the next night
# **Soldier** Cannot be killed by the demon at night
# **Tea Lady** If both of your living neighbors are good, neither can die
#
# # **Outsider**
# **Drunk** You think you are a specific town role that is not in play, but your ability doesn’t work
# **Moleman*** Each night, choose three living players (before anyone dies that night). If one is executed the following day, one of the other two, if alive, will be instead
# **Ogre*** On the first night, pick a player. You are their alignment for the rest of the game, but are not told what that alignment is
# **Recluse** May register as some manner of evil to other role abilities, even after dying
# **Sweetheart** When you die, a player becomes a drunk for the rest of the game
#
# # **Minion**
# **Baron** +2 Outsiders
# **Poisoner** Nightly, poison 1 player until the next night begins
# **Scarlet Woman** If the demon dies when there are 5 or more people alive, you become the demon
# **Spy** Nightly, learn all roles. You may appear as good to role abilities
# **Witch** Nightly, choose a player. If they nominate someone, they die. This ability is disabled the moment 3 or less people remain alive
#
# # **Demon**
# **Fang Gu** Nightly, choose a living player to die. The first time per game an outsider is killed like this, the original Fang Gu dies and the targeted outsider becomes the new Fang Gu. +1 Outsider instead of town
# **Ojo** Nightly, choose a role. If a player with that role exists, they die. If nobody has the role, the storyteller decides who dies
# **Prisdelo*** Nightly, choose 3 living players. Each is informed that they have been selected. Each must individually choose whether to live or die. If all choose to live, all die
